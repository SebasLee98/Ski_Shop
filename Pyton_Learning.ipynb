# %%
# Load excel file
import openpyxl as xl
wb = xl.load_workbook(filename = 'maven_ski_shop_data.xlsx')

# %%
# Create list without including the column title
inventory = wb['Orders_Info']
subtotals = []

for row in range(2, inventory.max_row + 1):
    subtotals.append(inventory[f'D{row}'].value)

subtotals
# Out:
# [15.98,
#  899.97,
#  799.97,
#  117.96,
#  5.99,
#  599.99,
#  24.99,
#  1799.94,
#  99.99,
#  254.95,
#  29.98,
#  99.99,
#  25.98,
#  649.98,
#  89.99,
#  119.99,
#  599.99,
#  649.98,
#  24.99,
#  99.99,
#  99.99,
#  5.99,
#  24.99,
#  999.96,
#  99.99,
#  399.97,
#  89.99]

# %%
# Calculate discount prices for customers that meet a certain criteria
discount_prices = []

for total in subtotals:
    if total > 500:
        discount_prices.append(total - (total*.2))
    else:
        discount_prices.append(total)

discount_prices
# Out:
# [15.98,
#  719.976,
#  639.976,
#  117.96,
#  5.99,
#  479.992,
#  24.99,
#  1439.952,
#  99.99,
#  254.95,
#  29.98,
#  99.99,
#  25.98,
#  519.984,
#  89.99,
#  119.99,
#  479.992,
#  519.984,
#  24.99,
#  99.99,
#  99.99,
#  5.99,
#  24.99,
#  799.9680000000001,
#  99.99,
#  399.97,
#  89.99]

# %%
# Create a dictionary of customer ID's and their subtotals
inventory = wb['Orders_Info']

cust_subtotals = []
cust_id = []

for row in range(2, inventory.max_row + 1):
    cust_subtotals.append(inventory[f'D{row}'].value)

for row in range(2, inventory.max_row + 1):
    cust_id.append(inventory[f'B{row}'].value)

cust_info = {}
for i, cust in enumerate(cust_id):
    cust_info[cust] = cust_subtotals[i]

cust_info
# Out:
# {'C00004': 119.99,
#  'C00007': 899.97,
#  'C00015': 799.97,
#  'C00016': 89.99,
#  'C00020': 5.99,
#  'C00010': 399.97,
#  'C00006': 24.99,
#  'C00001': 99.99,
#  'C00003': 99.99,
#  'C00014': 254.95,
#  'C00005': 25.98,
#  'C00008': 99.99,
#  'C00013': 89.99,
#  'C00017': 599.99,
#  'C00019': 649.98,
#  'C00002': 24.99,
#  'C00021': 99.99,
#  'C00022': 5.99,
#  'C00018': 99.99}
