# %%
import openpyxl as xl
wb = xl.load_workbook(filename = 'maven_ski_shop_data.xlsx')

# %%
inventory = wb['Orders_Info']

totals = []

for row in range(2, inventory.max_row + 1):
    totals.append(inventory[f'D{row}'].value)

totals
# Out:
# [15.98,
#  899.97,
#  799.97,
#  117.96,
#  5.99,
#  599.99,
#  24.99,
#  1799.94,
#  99.99,
#  254.95,
#  29.98,
#  99.99,
#  25.98,
#  649.98,
#  89.99,
#  119.99,
#  599.99,
#  649.98,
#  24.99,
#  99.99,
#  99.99,
#  5.99,
#  24.99,
#  999.96,
#  99.99,
#  399.97,
#  89.99]
