# %%
# Import pandas and set up the order info sheet

import pandas as pd

df = pd.read_excel('maven_ski_shop_data.xlsx', sheet_name=2)

df
# Out:
#     Order_ID Customer_ID  Order_Date  Subtotal  Tax  Total    Location  \
# 0     100000      C00004  11/26/2021     15.98  NaN    NaN  Sun Valley
# 1     100001      C00007  11/26/2021    899.97  NaN    NaN       Stowe
# 2     100002      C00015  11/26/2021    799.97  NaN    NaN     Mammoth
# 3     100003      C00016  11/26/2021    117.96  NaN    NaN       Stowe
# 4     100004      C00020  11/26/2021      5.99  NaN    NaN  Sun Valley
# 5     100005      C00010  11/26/2021    599.99  NaN    NaN     Mammoth
# 6     100006      C00006  11/26/2021     24.99  NaN    NaN     Mammoth
# 7     100007      C00001  11/26/2021   1799.94  NaN    NaN     Mammoth
# 8     100008      C00003  11/26/2021     99.99  NaN    NaN  Sun Valley
# 9     100009      C00014  11/26/2021    254.95  NaN    NaN  Sun Valley
# 10    100010      C00001  11/26/2021     29.98  NaN    NaN     Mammoth
# 11    100011      C00001  11/26/2021     99.99  NaN    NaN     Mammoth
# ...
